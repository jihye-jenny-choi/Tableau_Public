# %% [markdown]
# ## Dashboard for a Media Company

# %% [markdown]
# ![Dashboard%20-%20Session%203.jpg](attachment:Dashboard%20-%20Session%203.jpg)

# %% [markdown]
# ![Dashboard%20-%20User%202.jpg](attachment:Dashboard%20-%20User%202.jpg)
